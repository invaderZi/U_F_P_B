# %%
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %%
from sklearn.model_selection import train_test_split, KFold
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
def normalize(df_in, col_name):
    max_value = df_in[col_name].max()
    min_value = df_in[col_name].min()
    df_out = df_in.copy()
    df_out[col_name] = (df_in[col_name] - min_value) / (max_value - min_value)
    return df_out

# %%
df = pd.read_csv("Metro_Interstate_Traffic_Volume.csv")

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.shape
# Out:
# (48204, 9)

# %%
df['traffic_volume'].max()
# Out:
# 7280

# %%
df['traffic_volume'].min()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume'],
#       dtype='object')

# %%
df[df.duplicated(keep=False)].count()
# Out:
# holiday                34
# temp                   34
# rain_1h                34
# snow_1h                34
# clouds_all             34
# weather_main           34
# weather_description    34
# date_time              34
# traffic_volume         34
# dtype: int64

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# holiday                0
# temp                   0
# rain_1h                0
# snow_1h                0
# clouds_all             0
# weather_main           0
# weather_description    0
# date_time              0
# traffic_volume         0
# dtype: int64

# %%
print(df['holiday'].unique())
print(df['weather_main'].unique())
print(df['weather_description'].unique())
# Out:
# ['None' 'Columbus Day' 'Veterans Day' 'Thanksgiving Day' 'Christmas Day'
#  'New Years Day' 'Washingtons Birthday' 'Memorial Day' 'Independence Day'
#  'State Fair' 'Labor Day' 'Martin Luther King Jr Day']
# ['Clouds' 'Clear' 'Rain' 'Drizzle' 'Mist' 'Haze' 'Fog' 'Thunderstorm'
#  'Snow' 'Squall' 'Smoke']
# ['scattered clouds' 'broken clouds' 'overcast clouds' 'sky is clear'
#  'few clouds' 'light rain' 'light intensity drizzle' 'mist' 'haze' 'fog'
#  'proximity shower rain' 'drizzle' 'moderate rain' 'heavy intensity rain'
#  'proximity thunderstorm' 'thunderstorm with light rain'
#  'proximity thunderstorm with rain' 'heavy snow' 'heavy intensity drizzle'
#  'snow' 'thunderstorm with heavy rain' 'freezing rain' 'shower snow'
#  'light rain and snow' 'light intensity shower rain' 'SQUALLS'
#  'thunderstorm with rain' 'proximity thunderstorm with drizzle'
#  'thunderstorm' 'Sky is Clear' 'very heavy rain'
#  'thunderstorm with light drizzle' 'light snow'
#  'thunderstorm with drizzle' 'smoke' 'shower drizzle' 'light shower snow'
#  'sleet']

# %%
df['holiday'] = LabelEncoder().fit_transform(df['holiday'])
df['weather_main'] = LabelEncoder().fit_transform(df['weather_main'])
df['weather_description'] = LabelEncoder().fit_transform(df['weather_description'])

# %%
df.head()
# Out:
#    holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0        7  288.28      0.0      0.0          40             1
# 1        7  289.36      0.0      0.0          75             1
# 2        7  289.58      0.0      0.0          90             1
# 3        7  290.13      0.0      0.0          90             1
# 4        7  291.14      0.0      0.0          75             1
#
#    weather_description            date_time  traffic_volume
# 0                   24  2012-10-02 09:00:00            5545
# 1                    2  2012-10-02 10:00:00            4516
# 2                   19  2012-10-02 11:00:00            4767
# 3                   19  2012-10-02 12:00:00            5026
# 4                    2  2012-10-02 13:00:00            4918

# %%
data = df

# %%
data['date_time'] = pd.to_datetime(data['date_time'])
data['date'] = data['date_time'].dt.date
data['hour'] = data['date_time'].dt.hour
data['weekday'] = data['date_time'].dt.weekday


data = data.drop(columns=['date_time'])

data.head()
# Out:
#    holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0        7  288.28      0.0      0.0          40             1
# 1        7  289.36      0.0      0.0          75             1
# 2        7  289.58      0.0      0.0          90             1
# 3        7  290.13      0.0      0.0          90             1
# 4        7  291.14      0.0      0.0          75             1
#
#    weather_description  traffic_volume        date  hour  weekday
# 0                   24            5545  2012-10-02     9        1
# 1                    2            4516  2012-10-02    10        1
# 2                   19            4767  2012-10-02    11        1
# 3                   19            5026  2012-10-02    12        1
# 4                    2            4918  2012-10-02    13        1

# %%
correl = data.corr()
correl.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col5 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col6 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col8 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row0_col9 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col6 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col7 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col8 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row1_col9 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col8 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row2_col9 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col6 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col8 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row3_col9 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col3 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col5 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col7 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col8 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row4_col9 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col4 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col6 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col7 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5c211338_659f_11ea_a49e_3d9426c9a9c9row5_col9 {
#             background-color:  #5875e1;
#             color:  #000000;

# %% [markdown]
# # primeira abordagem

# %%
data2 = df

# %%
data2['date_time'] = pd.to_datetime(data2['date_time'])
data2['year'] = data2['date_time'].dt.year
data2['month'] = data2['date_time'].dt.month
data2['day'] = data2['date_time'].dt.day
data2['hour'] = data2['date_time'].dt.hour
data2['weekday'] = data2['date_time'].dt.weekday


data2 = data2.drop(columns=['date_time'])

data2.head()
# Out:
#    holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0        7  288.28      0.0      0.0          40             1
# 1        7  289.36      0.0      0.0          75             1
# 2        7  289.58      0.0      0.0          90             1
# 3        7  290.13      0.0      0.0          90             1
# 4        7  291.14      0.0      0.0          75             1
#
#    weather_description  traffic_volume        date  hour  weekday  year  \
# 0                   24            5545  2012-10-02     9        1  2012
# 1                    2            4516  2012-10-02    10        1  2012
# 2                   19            4767  2012-10-02    11        1  2012
# 3                   19            5026  2012-10-02    12        1  2012
# 4                    2            4918  2012-10-02    13        1  2012
#
#    month  day
# 0     10    2
# 1     10    2
# 2     10    2
# 3     10    2
# 4     10    2

# %%
    data2 = normalize(data2, 'temp')
    data2 = normalize(data2, 'rain_1h')
    data = normalize(data2, 'snow_1h')
    data2 = normalize(data2, 'clouds_all')
    #data2 = normalize(data2, 'traffic_volume')
    data2 = normalize(data2, 'hour')
    data2 = normalize(data2, 'weekday')
    data2 = normalize(data2, 'holiday')
    data2 = normalize(data2, 'date')
    data2 = normalize(data2, 'year')
    data2 = normalize(data2, 'month')
    data2 = normalize(data2, 'day')

# %%
data2.head()
# Out:
#     holiday      temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0  0.636364  0.929726      0.0      0.0        0.40             1
# 1  0.636364  0.933209      0.0      0.0        0.75             1
# 2  0.636364  0.933918      0.0      0.0        0.90             1
# 3  0.636364  0.935692      0.0      0.0        0.90             1
# 4  0.636364  0.938949      0.0      0.0        0.75             1
#
#    weather_description  traffic_volume  date      hour   weekday  year  \
# 0                   24            5545   0.0  0.391304  0.166667   0.0
# 1                    2            4516   0.0  0.434783  0.166667   0.0
# 2                   19            4767   0.0  0.478261  0.166667   0.0
# 3                   19            5026   0.0  0.521739  0.166667   0.0
# 4                    2            4918   0.0  0.565217  0.166667   0.0
#
#       month       day
# 0  0.818182  0.033333
# 1  0.818182  0.033333
# 2  0.818182  0.033333
# 3  0.818182  0.033333
# 4  0.818182  0.033333

# %%
correl = data2.corr()
correl.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col5 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col6 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col9 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col10 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col11 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col12 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row0_col13 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col6 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col7 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col8 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col10 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col11 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col12 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row1_col13 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col9 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col10 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col11 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col12 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row2_col13 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col6 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col9 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col10 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col11 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col12 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row3_col13 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row4_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row4_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5cefb0f8_659f_11ea_a49e_3d9426c9a9c9row4_col3 {
#             background-color:  #485fd1;
#             colo

# %% [markdown]
# # oficial start

# %%
scaler = preprocessing.StandardScaler()
data3 = data2
data3.head()
# Out:
#     holiday      temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0  0.636364  0.929726      0.0      0.0        0.40             1
# 1  0.636364  0.933209      0.0      0.0        0.75             1
# 2  0.636364  0.933918      0.0      0.0        0.90             1
# 3  0.636364  0.935692      0.0      0.0        0.90             1
# 4  0.636364  0.938949      0.0      0.0        0.75             1
#
#    weather_description  traffic_volume  date      hour   weekday  year  \
# 0                   24            5545   0.0  0.391304  0.166667   0.0
# 1                    2            4516   0.0  0.434783  0.166667   0.0
# 2                   19            4767   0.0  0.478261  0.166667   0.0
# 3                   19            5026   0.0  0.521739  0.166667   0.0
# 4                    2            4918   0.0  0.565217  0.166667   0.0
#
#       month       day
# 0  0.818182  0.033333
# 1  0.818182  0.033333
# 2  0.818182  0.033333
# 3  0.818182  0.033333
# 4  0.818182  0.033333

# %%
correl = data3.corr()
correl.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col5 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col6 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col9 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col10 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col11 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col12 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row0_col13 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col6 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col7 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col8 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col10 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col11 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col12 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row1_col13 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col9 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col10 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col11 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col12 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row2_col13 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col6 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col8 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col9 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col10 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col11 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col12 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row3_col13 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row4_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row4_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5d0d2bc4_659f_11ea_a49e_3d9426c9a9c9row4_col3 {
#             background-color:  #485fd1;
#             colo

# %%
data3.shape
# Out:
# (48187, 14)

# %%
data3 = data3.drop(columns=['day'])
data3 = data3.drop(columns=['month'])
data3 = data3.drop(columns=['year'])
data3 = data3.drop(columns=['snow_1h'])
data3 = data3.drop(columns=['rain_1h'])

# %%
data3.head()
# Out:
#     holiday      temp  clouds_all  weather_main  weather_description  \
# 0  0.636364  0.929726        0.40             1                   24
# 1  0.636364  0.933209        0.75             1                    2
# 2  0.636364  0.933918        0.90             1                   19
# 3  0.636364  0.935692        0.90             1                   19
# 4  0.636364  0.938949        0.75             1                    2
#
#    traffic_volume  date      hour   weekday
# 0            5545   0.0  0.391304  0.166667
# 1            4516   0.0  0.434783  0.166667
# 2            4767   0.0  0.478261  0.166667
# 3            5026   0.0  0.521739  0.166667
# 4            4918   0.0  0.565217  0.166667

# %%
correl = data3.corr()
correl.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col2 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col3 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col7 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row0_col8 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col2 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col3 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col4 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col6 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col7 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row1_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col3 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col5 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row2_col8 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col2 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col5 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row3_col8 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col1 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col5 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col6 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row4_col8 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col1 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col2 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col6 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col7 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row5_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row6_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row6_col1 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row6_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row6_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row6_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_5d419940_659f_11ea_a49e_3d9426c9a9c9row6_col5 {
#             background-color:  #6485ec;
#             color:  #000000;

# %%
apend = data3['traffic_volume']
data3 = data3.drop(columns=['traffic_volume'])
data3['traffic'] = apend.values

# %%
data3 = data3.drop(columns=['date'])

# %%
data3.head()
# Out:
#     holiday      temp  clouds_all  weather_main  weather_description  \
# 0  0.636364  0.929726        0.40             1                   24
# 1  0.636364  0.933209        0.75             1                    2
# 2  0.636364  0.933918        0.90             1                   19
# 3  0.636364  0.935692        0.90             1                   19
# 4  0.636364  0.938949        0.75             1                    2
#
#        hour   weekday  traffic
# 0  0.391304  0.166667     5545
# 1  0.434783  0.166667     4516
# 2  0.478261  0.166667     4767
# 3  0.521739  0.166667     5026
# 4  0.565217  0.166667     4918

# %%
print (data3.shape)
# Out:
# (48187, 8)

# %%
data3 = normalize(data3, 'weather_main')
data3 = normalize(data3, 'weather_description')

# %%
data3.head()
# Out:
#     holiday      temp  clouds_all  weather_main  weather_description  \
# 0  0.636364  0.929726        0.40           0.1             0.648649
# 1  0.636364  0.933209        0.75           0.1             0.054054
# 2  0.636364  0.933918        0.90           0.1             0.513514
# 3  0.636364  0.935692        0.90           0.1             0.513514
# 4  0.636364  0.938949        0.75           0.1             0.054054
#
#        hour   weekday  traffic
# 0  0.391304  0.166667     5545
# 1  0.434783  0.166667     4516
# 2  0.478261  0.166667     4767
# 3  0.521739  0.166667     5026
# 4  0.565217  0.166667     4918

# %%
correl = data3.corr()
correl.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col2 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col3 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col6 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row0_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col2 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col3 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col4 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row1_col7 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col3 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col6 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row2_col7 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col2 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col6 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row3_col7 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col1 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col5 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col6 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row4_col7 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col0 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col1 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col2 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col3 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col4 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col6 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row5_col7 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col1 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col2 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col3 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col4 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col5 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row6_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row7_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row7_col1 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row7_col2 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_5dbf36b6_659f_11ea_a49e_3d9426c9a9c9row7_col3 {
#             background-color:  #516ddb;
#             color:  #000000;

# %%
dataNOnorm = data3

# %%
data3 = normalize(data3, 'traffic')

# %% [markdown]
# # train-test

# %%
x = data3.iloc[:, :7]
y = data3['traffic']

# %%
x.head()
# Out:
#     holiday      temp  clouds_all  weather_main  weather_description  \
# 0  0.636364  0.929726        0.40           0.1             0.648649
# 1  0.636364  0.933209        0.75           0.1             0.054054
# 2  0.636364  0.933918        0.90           0.1             0.513514
# 3  0.636364  0.935692        0.90           0.1             0.513514
# 4  0.636364  0.938949        0.75           0.1             0.054054
#
#        hour   weekday
# 0  0.391304  0.166667
# 1  0.434783  0.166667
# 2  0.478261  0.166667
# 3  0.521739  0.166667
# 4  0.565217  0.166667

# %%
y.head()
# Out:
# 0    0.761676
# 1    0.620330
# 2    0.654808
# 3    0.690385
# 4    0.675549
# Name: traffic, dtype: float64

# %%
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn import metrics as me

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=9, shuffle = True)
x_train2, x_test2, y_train2, y_test2 = train_test_split(x, y, test_size=0.3, random_state=19, shuffle = True)

# %%
x_train.shape
# Out:
# (33730, 7)

# %%
x_test.shape
# Out:
# (14457, 7)

# %%
y_train.shape
# Out:
# (33730,)

# %%
y_test.shape
# Out:
# (14457,)

# %%
def metrics(target, result, model = "Unnamed"):
    print(model)
    print("MSE: %0.5f" % (me.mean_squared_error(target, result)))
    print("MAD: %0.5f" % (me.mean_absolute_error(target, result)))
    print("R2: %0.5f" % (me.r2_score(target, result)))
    print("")

# %% [markdown]
# As métricas de desempenho : o erro médio quadrático (MSE), erro médio absoluto (MAD) e o coeficiente de determinação (R2).
# Para os dois primeiros, valores próximos de 0 indicam um modelo com baixo erro, enquanto para o último um valor igual a 1 indica que o modelo se ajusta perfeitamente aos dados.

# %%
classifier = tree.DecisionTreeRegressor(random_state = 42)
classifier.fit(x_train, y_train)
predictions = classifier.predict(x_test)


classifier2 = tree.DecisionTreeRegressor(random_state = 42)
classifier2.fit(x_train2, y_train2)
predictions2 = classifier2.predict(x_test2)

# %%
metrics(y_test, predictions, "tree 1")
metrics(y_test2, predictions2, "tree 2")
# Out:
# tree 1
# MSE: 0.00754
# MAD: 0.04633
# R2: 0.89841
#
# tree 2
# MSE: 0.00812
# MAD: 0.04793
# R2: 0.88997

# %%
from sklearn import neighbors, svm

# %%
x_train3, x_test3, y_train3, y_test3 = train_test_split(x, y, test_size=0.3, random_state=25, shuffle = True)
x_train4, x_test4, y_train4, y_test4 = train_test_split(x, y, test_size=0.3, random_state=123, shuffle = True)

# %%
k1 = 3
k2 = 5
classifier3 = neighbors.KNeighborsRegressor(n_neighbors = k1)
classifier3.fit(x_train3, y_train3)
predictions3 = classifier.predict(x_test3)


classifier4 = neighbors.KNeighborsRegressor(n_neighbors = k2)
classifier4.fit(x_train4, y_train4)
predictions4 = classifier2.predict(x_test4)

# %%
metrics(y_test3, predictions3, "knn  k = 3")
metrics(y_test4, predictions4, "knn k = 5 ")
# Out:
# knn  k = 3
# MSE: 0.00237
# MAD: 0.01465
# R2: 0.96802
#
# knn k = 5
# MSE: 0.00242
# MAD: 0.01443
# R2: 0.96758

# %%
classifier = svm.SVR(kernel='linear')
classifier.fit(x_train, y_train)
predictions = classifier.predict(x_test)


classifier2 = svm.SVR(kernel='linear')
classifier2.fit(x_train2, y_train2)
predictions2 = classifier2.predict(x_test2)

# %%
metrics(y_test, predictions, "SVM 1")
metrics(y_test2, predictions2, "SVM 2")
# Out:
# SVM 1
# MSE: 0.06303
# MAD: 0.21402
# R2: 0.15115
#
# SVM 2
# MSE: 0.06407
# MAD: 0.21578
# R2: 0.13205

# %% [markdown]
# # validacao cruzada

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score

# %%
predicoes = data3;


num = predicoes.select_dtypes(['float64', 'int64']).columns.values
num = np.delete(num, np.argwhere(num == 'traffic'))

scaler = preprocessing.MinMaxScaler()
scaled = pd.concat([pd.DataFrame(scaler.fit_transform(predicoes[num]), columns = num), dataNOnorm['traffic']], axis=1)

scaled.head()
# Out:
#     holiday      temp  clouds_all  weather_main  weather_description  \
# 0  0.636364  0.929726        0.40           0.1             0.648649
# 1  0.636364  0.933209        0.75           0.1             0.054054
# 2  0.636364  0.933918        0.90           0.1             0.513514
# 3  0.636364  0.935692        0.90           0.1             0.513514
# 4  0.636364  0.938949        0.75           0.1             0.054054
#
#        hour   weekday  traffic
# 0  0.391304  0.166667   5545.0
# 1  0.434783  0.166667   4516.0
# 2  0.478261  0.166667   4767.0
# 3  0.521739  0.166667   5026.0
# 4  0.565217  0.166667   4918.0

# %%
kf = model_selection.KFold(n_splits=10,random_state=42, shuffle=True)

knn = neighbors.KNeighborsRegressor(n_neighbors=3)
tee = tree.DecisionTreeRegressor()

# %%
splits = 10
results = []
fold = model_selection.KFold(n_splits = splits, random_state = 7, shuffle = True)

x = dataNOnorm.copy(deep = True)
y = x['traffic']

x.drop(columns = ['traffic'], inplace = True)

x = x.reset_index()
y = y.reset_index()

# %%
msetree=[]

for train_index, test_index in kf.split(data3):
    x_train, x_test = x.loc[train_index], x.loc[test_index]
    y_train, y_test = y.loc[train_index], y.loc[test_index]
    knn.fit(x_train,y_train)
    resultknn = knn.predict(x_test)
    
    tee.fit(x_train,y_train)
    resulttree = tee.predict(x_test)
    
    
    metrics(y_test, resultknn, "knn metrics")
 
    
    print("Validação Cruzada - KNN")
    print("MSE = %0.5f" % (me.mean_squared_error(y_test,resultknn)))
    print("MAE = %0.5f" % (me.mean_absolute_error(y_test,resultknn)))
    print("R² = %0.5f" % (me.r2_score(y_test,resultknn)))


    print("\nValidação Cruzada - Árvore de Decisão")
    print("MSE = % 0.5f" % (me.mean_squared_error(y_test,resulttree)))
    print("MAE = %0.5f" % (me.mean_absolute_error(y_test,resulttree)))
    print("R² = %0.5f" % (me.r2_score(y_test,resulttree)))

    print('\n')
# Out:
# tree metrics
# MSE: 251803.56235
# MAD: 232.20914
# R2: 0.93672
#
# Validação Cruzada - KNN
# MSE = 251803.56235
# MAE = 232.20914
# R² = 0.93672
#
# Validação Cruzada - Árvore de Decisão
# MSE =  72196.13654
# MAE = 131.69392
# R² = 0.98288
#
#
# tree metrics
# MSE: 234196.18036
# MAD: 223.64062
# R2: 0.94170
#
# Validação Cruzada - KNN
# MSE = 234196.18036
# MAE = 223.64062
# R² = 0.94170
#
# Validação Cruzada - Árvore de Decisão
# MSE =  76003.73428
# MAE = 133.94449
# R² = 0.98209
#
#
# tree metrics
# MSE: 253672.51326
# MAD: 232.46970
# R2: 0.93677
#
# Validação Cruzada - KNN
# MSE = 253672.51326
# MAE = 232.46970
# R² = 0.93677
#
# Validação Cruzada - Árvore de Decisão
# MSE =  73005.77475
# MAE = 131.83804
# R² = 0.98294
#
#
# tree metrics
# MSE: 251549.69347
# MAD: 234.12101
# R2: 0.93678
#
# Validação Cruzada - KNN
# MSE = 251549.69347
# MAE = 234.12101
# R² = 0.93678
#
# Validação Cruzada - Árvore de Decisão
# MSE =  79316.00540
# MAE = 138.75846
# R² = 0.98130
#
#
# tree metrics
# MSE: 233577.94655
# MAD: 226.78094
# R2: 0.94059
#
# Validação Cruzada - KNN
# MSE = 233577.94655
# MAE = 226.78094
# R² = 0.94059
#
# Validação Cruzada - Árvore de Decisão
# MSE =  76933.28751
# MAE = 133.99160
# R² = 0.98154
#
#
# tree metrics
# MSE: 249134.27185
# MAD: 233.62907
# R2: 0.93609
#
# Validação Cruzada - KNN
# MSE = 249134.27185
# MAE = 233.62907
# R² = 0.93609
#
# Validação Cruzada - Árvore de Decisão
# MSE =  82517.23843
# MAE = 137.96410
# R² = 0.98006
#
#
# tree metrics
# MSE: 240509.26442
# MAD: 225.93539
# R2: 0.93817
#
# Validação Cruzada - KNN
# MSE = 240509.26442
# MAE = 225.93539
# R² = 0.93817
#
# Validação Cruzada - Árvore de Decisão
# MSE =  74770.24632
# MAE = 132.22432
# R² = 0.98191
#
#
# tree metrics
# MSE: 234955.94842
# MAD: 226.33759
# R2: 0.93958
#
# Validação Cruzada - KNN
# MSE = 234955.94842
# MAE = 226.33759
# R² = 0.93958
#
# Validação Cruzada - Árvore de Decisão
# MSE =  77487.68244
# MAE = 136.63782
# R² = 0.98124
#
#
# tree metrics
# MSE: 251941.50389
# MAD: 233.57302
# R2: 0.93610
#
# Validação Cruzada - KNN
# MSE = 251941.50389
# MAE = 233.57302
# R² = 0.93610
#
# Validação Cruzada - Árvore de Decisão
# MSE =  77865.25758
# MAE = 135.71295
# R² = 0.98128
#
#
# tree metrics
# MSE: 257575.92122
# MAD: 237.00284
# R2: 0.93459
#
# Validação Cruzada - KNN
# MSE = 257575.92122
# MAE = 237.00284
# R² = 0.93459
#
# Validação Cruzada - Árvore de Decisão
# MSE =  78440.41511
# MAE = 138.29058
# R² = 0.98113

# %%
from sklearn.model_selection import cross_val_score

scores1 = cross_val_score(knn, x, y, cv = fold, scoring= 'neg_mean_squared_error')
scores2 = cross_val_score(tee, x, y, cv=fold, scoring='neg_mean_squared_error' )

scores3 = cross_val_score(knn, x, y, cv=fold, scoring='neg_mean_absolute_error' )
scores4 = cross_val_score(tee, x, y, cv=fold, scoring='neg_mean_absolute_error')


scores5 = cross_val_score(knn, x, y, cv=fold, scoring='r2')
scores6 = cross_val_score(tee, x, y, cv=fold,scoring='r2')

# %%
from sklearn import cross_validation model = RandomForestClassifier(n_estimators=100) #Simple K-Fold cross validation. 5 folds. #(Note: in older scikit-learn versions the "n_folds" argument is named "k".) cv = cross_validation.KFold(len(train), n_folds=5, indices=False) results = [] # "model" can be replaced by your model object # "Error_function" can be replaced by the error function of your analysis for traincv, testcv in cv:             probas = model.fit(train[traincv], target[traincv]).predict_proba(train[testcv])             results.append( Error_function ) #print out the mean of the cross-validated results print "Results: " + str( np.array(results).mean() )

# %%
print(scores1,'\n\n\n',scores2,'\n\n\n',scores3,'\n\n\n',scores4,'\n\n',scores5,'\n\n',scores6)
# Out:
# [-242984.68012035 -231737.18575776 -239772.208757   -253554.50379286
#  -227347.56436328 -231087.91100043 -239025.83108528 -249923.12218071
#  -251334.27196624 -243357.76911812]
#
#
#  [-75578.63851421 -81476.117348   -92429.95445113 -71393.29186553
#  -74713.6444283  -71093.85401536 -80367.62326209 -79407.39809049
#  -77994.48619759 -79454.70257368]
#
#
#  [-228.3510756  -226.95680293 -228.71812963 -233.89057204 -223.48799889
#  -225.1437366  -228.04627516 -234.07409714 -231.05251142 -230.75927079]
#
#
#  [-134.22556547 -138.37964308 -140.00601785 -134.86376842 -131.60583109
#  -132.98744553 -136.38368956 -137.03455791 -135.88428809 -138.67382731]
#
#  [0.93884709 0.94144817 0.93890534 0.93590841 0.94162591 0.94109377
#  0.93984743 0.93704585 0.93667033 0.9381394 ]
#
#  [0.98241742 0.98025929 0.97806864 0.98284345 0.98158047 0.98239871
#  0.98033527 0.98146408 0.98096741 0.9811455 ]

# %%
print('mean sq error \n', 'knn:', scores1.mean(),'\ntree: ',scores2.mean(),'\n\n','mean absolut eror\n', 'knn: ', scores3.mean() , '\ntree: ' , scores4.mean() , '\n\nR² \n \n' , 'knn:' , scores5.mean(), '\ntree:' , scores6.mean())
# Out:
# mean sq error
#  knn: -241012.50481420424
# tree:  -78390.97107463916
#
#  mean absolut eror
#  knn:  -229.0480470196998
# tree:  -136.00446342961834
#
# R²
#
#  knn: 0.9389531698832323
# tree: 0.9811480229780569
